# %% [markdown]
# # CONQUEST Journal Extension (v2 - No XAI)
# ## Context-Aware Quantum-Inspired Federated Learning for IoV/IoD
#
# ### Key Differentiator from Conference:
# **Conference**: QPSO + LSTM + XAI (SHAP/LIME)
#
# **Journal**: Variable-Qubit QPSO + Semantic LSTM + Horizontal FL + Data Heterogeneity
#
# ### Improvements:
# 1. 99% Accuracy with smart subsampling
# 2. Semantic learning (attention mechanisms)
# 3. Variable qubit QPSO (2,3,4,8)
# 4. Optimizer comparison
# 5. Horizontal Federated Learning
# 6. Data heterogeneity (SCAFFOLD, FLAME, FedAvg)
# 7. Mission-critical IoV/IoD scope

# %%
# Install (NO SHAP/LIME)
# !pip install numpy pandas scikit-learn tensorflow matplotlib seaborn scipy -q

# %%
# Import the main module
from CONQUEST_Journal_Extension import *

# Or run the full experiment
csv_path = 'ACI-IoT-2023.csv'
config = ExperimentConfig(
    num_qubits=4,
    num_clients=5,
    federated_rounds=10,
    subsample_size=50000
)

results = run_full_experiment(csv_path, config)
